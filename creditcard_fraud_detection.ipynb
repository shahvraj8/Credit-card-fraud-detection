# %%
#Importing required libraries

import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


from sklearn.model_selection import train_test_split

from imblearn.over_sampling import SMOTE

from sklearn.linear_model import LogisticRegression 
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier



from sklearn.metrics import accuracy_score,confusion_matrix

# %% [markdown]
# **Uploading dataset and Datapreprocessing**

# %%
data = pd.read_csv("/content/drive/MyDrive/creditcard.csv")  
data.drop("Time", axis=1,inplace=True)
print(data.shape)
data.head()
# Out:
# (284807, 30)
#          V1        V2        V3        V4  ...       V27       V28  Amount  Class
# 0 -1.359807 -0.072781  2.536347  1.378155  ...  0.133558 -0.021053  149.62      0
# 1  1.191857  0.266151  0.166480  0.448154  ... -0.008983  0.014724    2.69      0
# 2 -1.358354 -1.340163  1.773209  0.379780  ... -0.055353 -0.059752  378.66      0
# 3 -0.966272 -0.185226  1.792993 -0.863291  ...  0.062723  0.061458  123.50      0
# 4 -1.158233  0.877737  1.548718  0.403034  ...  0.219422  0.215153   69.99      0
#
# [5 rows x 30 columns]

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 284807 entries, 0 to 284806
# Data columns (total 30 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   V1      284807 non-null  float64
#  1   V2      284807 non-null  float64
#  2   V3      284807 non-null  float64
#  3   V4      284807 non-null  float64
#  4   V5      284807 non-null  float64
#  5   V6      284807 non-null  float64
#  6   V7      284807 non-null  float64
#  7   V8      284807 non-null  float64
#  8   V9      284807 non-null  float64
#  9   V10     284807 non-null  float64
#  10  V11     284807 non-null  float64
#  11  V12     284807 non-null  float64
#  12  V13     284807 non-null  float64
#  13  V14     284807 non-null  float64
#  14  V15     284807 non-null  float64
#  15  V16     284807 non-null  float64
#  16  V17     284807 non-null  float64
#  17  V18     284807 non-null  float64
#  18  V19     284807 non-null  float64
#  19  V20     284807 non-null  float64
# ...

# %%
data.describe()
# Out:
#                  V1            V2  ...         Amount          Class
# count  2.848070e+05  2.848070e+05  ...  284807.000000  284807.000000
# mean   3.919560e-15  5.688174e-16  ...      88.349619       0.001727
# std    1.958696e+00  1.651309e+00  ...     250.120109       0.041527
# min   -5.640751e+01 -7.271573e+01  ...       0.000000       0.000000
# 25%   -9.203734e-01 -5.985499e-01  ...       5.600000       0.000000
# 50%    1.810880e-02  6.548556e-02  ...      22.000000       0.000000
# 75%    1.315642e+00  8.037239e-01  ...      77.165000       0.000000
# max    2.454930e+00  2.205773e+01  ...   25691.160000       1.000000
#
# [8 rows x 30 columns]

# %% [markdown]
# **Data visualization and Removing outliers**

# %%
for u in data.columns:
  plt.title("{}".format(u))
  data[u].plot(kind="box")
  plt.show()

# %%
def outliers(col):  #Function whcich detects and remove the outliers
  global data
  lower = data[col].quantile(0.25)
  upper = data[col].quantile(0.75)

  diff = upper-lower

  lower_limit = lower - (1.5*diff)
  upper_limit = upper + (1.5*diff)

  data = data[(data[col]>lower_limit) & (data[col]<upper_limit)]

# %%
for col in data.columns[:-1]:
  outliers(col)

# %%
data.shape
# Out:
# (110122, 30)

# %%
for u in data.columns:
  plt.title("{}".format(u))
  data[u].plot(kind="box")
  plt.show()

# %% [markdown]
# It can be seen that significant numbers of outliers have been removed by the function

# %%
data.head()
# Out:
#           V1        V2        V3        V4  ...       V27       V28  Amount  Class
# 1   1.191857  0.266151  0.166480  0.448154  ... -0.008983  0.014724    2.69      0
# 5  -0.425966  0.960523  1.141109 -0.168252  ...  0.253844  0.081080    3.67      0
# 6   1.229658  0.141004  0.045371  1.202613  ...  0.034507  0.005168    4.99      0
# 9  -0.338262  1.119593  1.044367 -0.222187  ...  0.246219  0.083076    3.68      0
# 12  1.249999 -1.221637  0.383930 -1.234899  ...  0.026416  0.042422  121.50      0
#
# [5 rows x 30 columns]

# %%
sns.set(rc={'figure.figsize':(21.7,18.27)})
sns.heatmap(data.corr(),annot=True,fmt="0.01f")
plt.show()

# %%
#v1 and v3, v2 and v7, v5 and v7, v21 and v22 are linearly dependent features.so dropping feature[v1, v7, v21]

# %%
data.drop(["V1","V7","V21"],axis=1,inplace = True)

# %%
sns.set(rc={'figure.figsize':(21.7,18.27)})
sns.heatmap(data.corr(),annot=True,fmt="0.01f")

# %%
data["Class"].unique()
# Out:
# array([0, 1])

# %%
sns.set(rc={'figure.figsize':(5,3)})
sns.countplot(data["Class"])
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
len(data[data["Class"]==1])
# Out:
# 13

# %% [markdown]
# This is a highly unbalanced dataset so we will balance it by using **smote** method of  imblearn library

# %%
x = data.iloc[:,0:-1]  #Splitting dataset in to dependent and independent features
y = data.iloc[:,[-1]]

# %%
sm = SMOTE(random_state =101)

# %%
x,y = sm.fit_resample(x,y)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)

# %%
sns.countplot(y)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Dataset seemns to be balanced

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,stratify=y,random_state=1)

# %% [markdown]
# **Applying ML models**

# %% [markdown]
# Let create a function named perfromance to check the performance parameters of different algorithms.

# %%
def performance(y_test,y_pred):
  print(accuracy_score(y_test,y_pred))
  return confusion_matrix(y_test,y_pred)

# %% [markdown]
# Logistic regression model

# %%
model = LogisticRegression(solver="sag")

# %%
model.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='sag', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred = model.predict(x_test)

# %%
performance(y_test,y_pred)
# Out:
# 0.9234765234765234
# array([[24433,  3094],
#        [ 1119, 26409]])

# %% [markdown]
# kneighborsclassifier model

# %%
knn = KNeighborsClassifier(n_neighbors=11)
knn.fit(x_train,y_train)
y_pred_knn = knn.predict(x_test)

# %%
performance(y_test,y_pred_knn)
# Out:
# 0.9958041958041958
# array([[27296,   231],
#        [    0, 27528]])

# %% [markdown]
# Random forest classifier

# %%
rfc = RandomForestClassifier()

# %%
rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
y_pred_rfc = rfc.predict(x_test)

# %%
performance(y_test,y_pred_rfc)
# Out:
# 0.9999818363454727
# array([[27526,     1],
#        [    0, 27528]])

# %% [markdown]
# Conclusion: So over here along with the accuracy false negative also playes an important role.
# so randomforest and knn both give good accuracy and zero false negative for this particular dataset.
